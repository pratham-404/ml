# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('./data/aapl.csv', parse_dates=['Date'], index_col='Date') # IMP('Date' as DateTime-index & setting index to 'Date')
df
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017-07-07  142.90  144.75  142.90  144.18  19201712
# 2017-07-06  143.02  143.50  142.41  142.73  24128782
# 2017-07-05  143.69  144.79  142.72  144.09  21569557
# 2017-07-03  144.88  145.30  143.10  143.50  14277848
# 2017-06-30  144.45  144.96  143.78  144.02  23024107
# ...            ...     ...     ...     ...       ...
# 2016-07-15   98.92   99.30   98.50   98.78  30136990
# 2016-07-14   97.39   98.99   97.32   98.79  38918997
# 2016-07-13   97.41   97.67   96.84   96.87  25892171
# 2016-07-12   97.17   97.70   97.12   97.42  24167463
# 2016-07-11   96.75   97.65   96.73   96.98  23794945
#
# [251 rows x 5 columns]

# %%
df.loc["2017-01"].head() # Better indexing using datetime index
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017-01-31  121.15  121.39  120.62  121.35  49200993
# 2017-01-30  120.93  121.63  120.66  121.63  30377503
# 2017-01-27  122.14  122.35  121.60  121.95  20562944
# 2017-01-26  121.67  122.44  121.60  121.94  26337576
# 2017-01-25  120.42  122.10  120.28  121.88  32586673

# %%
# df['Close']
df['Close'].resample('M').mean() # resampling data in monthly frequency
# Out:
# Date
# 2016-07-31     99.473333
# 2016-08-31    107.665217
# 2016-09-30    110.857143
# 2016-10-31    115.707143
# 2016-11-30    110.154286
# 2016-12-31    114.335714
# 2017-01-31    119.570000
# 2017-02-28    133.713684
# 2017-03-31    140.617826
# 2017-04-30    142.886842
# 2017-05-31    152.227727
# 2017-06-30    147.831364
# 2017-07-31    143.625000
# Freq: M, Name: Close, dtype: float64

# %%
df['Close'].resample('M').mean().plot()  # plot of montly frequnency closing price of AAPL
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
df['Close'].resample('W').mean().plot()  # plot of weekly frequnency closing price of AAPL
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
df = pd.read_csv("./data/aapl_no_dates.csv")
# df

# we can use date range incase our dataset does not contain date as a column
range = pd.date_range(start="6/1/2017", end="6/30/2017", freq='B')
# range

df.set_index(range, inplace=True)
df
# Out:
#               Open    High     Low   Close    Volume
# 2017-06-01  153.17  153.33  152.22  153.18  16404088
# 2017-06-02  153.58  155.45  152.89  155.45  27770715
# 2017-06-05  154.34  154.45  153.46  153.93  25331662
# 2017-06-06  153.90  155.81  153.78  154.45  26624926
# 2017-06-07  155.02  155.98  154.48  155.37  21069647
# 2017-06-08  155.25  155.54  154.40  154.99  21250798
# 2017-06-09  155.19  155.19  146.02  148.98  64882657
# 2017-06-12  145.74  146.09  142.51  145.42  72307330
# 2017-06-13  147.16  147.45  145.15  146.59  34165445
# 2017-06-14  147.50  147.50  143.84  145.16  31531232
# 2017-06-15  143.32  144.48  142.21  144.29  32165373
# 2017-06-16  143.78  144.50  142.20  142.27  50361093
# 2017-06-19  143.66  146.74  143.66  146.34  32541404
# 2017-06-20  146.87  146.87  144.94  145.01  24900073
# 2017-06-21  145.52  146.07  144.61  145.87  21265751
# 2017-06-22  145.77  146.70  145.12  145.63  19106294
# 2017-06-23  145.13  147.16  145.11  146.28  35439389
# ...

# %%
# fillup holes in dataset using previous values usgin asfreq() method
df.asfreq('D', method='pad') # observe new index on weekends are created and set ot values of previous date's available data
# Out:
#               Open    High     Low   Close    Volume
# 2017-06-01  153.17  153.33  152.22  153.18  16404088
# 2017-06-02  153.58  155.45  152.89  155.45  27770715
# 2017-06-03  153.58  155.45  152.89  155.45  27770715
# 2017-06-04  153.58  155.45  152.89  155.45  27770715
# 2017-06-05  154.34  154.45  153.46  153.93  25331662
# 2017-06-06  153.90  155.81  153.78  154.45  26624926
# 2017-06-07  155.02  155.98  154.48  155.37  21069647
# 2017-06-08  155.25  155.54  154.40  154.99  21250798
# 2017-06-09  155.19  155.19  146.02  148.98  64882657
# 2017-06-10  155.19  155.19  146.02  148.98  64882657
# 2017-06-11  155.19  155.19  146.02  148.98  64882657
# 2017-06-12  145.74  146.09  142.51  145.42  72307330
# 2017-06-13  147.16  147.45  145.15  146.59  34165445
# 2017-06-14  147.50  147.50  143.84  145.16  31531232
# 2017-06-15  143.32  144.48  142.21  144.29  32165373
# 2017-06-16  143.78  144.50  142.20  142.27  50361093
# 2017-06-17  143.78  144.50  142.20  142.27  50361093
# ...

# %%
# we use shift mostly to calculate percentage change in prices
df.shift(1).head()
# Out:
#               Open    High     Low   Close      Volume
# 2017-06-01     NaN     NaN     NaN     NaN         NaN
# 2017-06-02  153.17  153.33  152.22  153.18  16404088.0
# 2017-06-05  153.58  155.45  152.89  155.45  27770715.0
# 2017-06-06  154.34  154.45  153.46  153.93  25331662.0
# 2017-06-07  153.90  155.81  153.78  154.45  26624926.0

# %%
df.shift(-1).tail()
# Out:
#               Open    High     Low   Close      Volume
# 2017-06-26  145.01  146.16  143.62  143.73  24761891.0
# 2017-06-27  144.49  146.11  143.16  145.83  22082432.0
# 2017-06-28  144.71  145.13  142.28  143.68  31499368.0
# 2017-06-29  144.45  144.96  143.78  144.02  23024107.0
# 2017-06-30     NaN     NaN     NaN     NaN         NaN

# %%
df['Prev. Close'] = df['Close'].shift(1)
df.head()
# Out:
#               Open    High     Low   Close    Volume  Prev. Close
# 2017-06-01  153.17  153.33  152.22  153.18  16404088          NaN
# 2017-06-02  153.58  155.45  152.89  155.45  27770715       153.18
# 2017-06-05  154.34  154.45  153.46  153.93  25331662       155.45
# 2017-06-06  153.90  155.81  153.78  154.45  26624926       153.93
# 2017-06-07  155.02  155.98  154.48  155.37  21069647       154.45

# %%
df["1 day change"] = df['Close'] - df["Prev. Close"]
df.head()
# Out:
#               Open    High     Low   Close    Volume  Prev. Close  \
# 2017-06-01  153.17  153.33  152.22  153.18  16404088          NaN
# 2017-06-02  153.58  155.45  152.89  155.45  27770715       153.18
# 2017-06-05  154.34  154.45  153.46  153.93  25331662       155.45
# 2017-06-06  153.90  155.81  153.78  154.45  26624926       153.93
# 2017-06-07  155.02  155.98  154.48  155.37  21069647       154.45
#
#             1 day change
# 2017-06-01           NaN
# 2017-06-02          2.27
# 2017-06-05         -1.52
# 2017-06-06          0.52
# 2017-06-07          0.92

# %%
df["5 day % change"] = (df['Close'] - df["Close"].shift(5))*100/(df["Close"].shift(5)) # smilarly we can also shift he index using tshift() in pandas
df.head()
# Out:
#               Open    High     Low   Close    Volume  Prev. Close  \
# 2017-06-01  153.17  153.33  152.22  153.18  16404088          NaN
# 2017-06-02  153.58  155.45  152.89  155.45  27770715       153.18
# 2017-06-05  154.34  154.45  153.46  153.93  25331662       155.45
# 2017-06-06  153.90  155.81  153.78  154.45  26624926       153.93
# 2017-06-07  155.02  155.98  154.48  155.37  21069647       154.45
#
#             1 day change  5 day % change
# 2017-06-01           NaN             NaN
# 2017-06-02          2.27             NaN
# 2017-06-05         -1.52             NaN
# 2017-06-06          0.52             NaN
# 2017-06-07          0.92             NaN
