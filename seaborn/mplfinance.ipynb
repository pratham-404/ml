# %%
# pip install mplfinance
# pip install yfinance

import matplotlib.pyplot as plt
import mplfinance as mpf
import datetime as dt
import yfinance as yf

# %%
start = dt.datetime(2013, 1, 1)
type(start)
# Out:
# datetime.datetime

# %%
start_date = dt.datetime(2016, 1, 1)
end_date = dt.datetime(2016, 1, 27)

data = yf.download('GOOGL',start_date,end_date)
data.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                                 Open       High        Low      Close  \
# Date
# 2016-01-04 00:00:00-05:00  38.110001  38.110001  37.376999  37.972000
# 2016-01-05 00:00:00-05:00  38.205002  38.459999  37.782501  38.076500
# 2016-01-06 00:00:00-05:00  37.518501  38.286499  37.400002  37.966499
# 2016-01-07 00:00:00-05:00  37.324501  37.765499  36.764000  37.049999
# 2016-01-08 00:00:00-05:00  37.389999  37.506001  36.445999  36.545502
#
#                            Adj Close    Volume
# Date
# 2016-01-04 00:00:00-05:00  37.972000  67382000
# 2016-01-05 00:00:00-05:00  38.076500  45216000
# 2016-01-06 00:00:00-05:00  37.966499  48206000
# 2016-01-07 00:00:00-05:00  37.049999  63132000
# 2016-01-08 00:00:00-05:00  36.545502  47506000

# %%
colors = mpf.make_marketcolors(up="#00ff00", down="#ff0000", wick="inherit", edge="inherit", volume="in")

mpf_style = mpf.make_mpf_style(base_mpf_style='nightclouds', marketcolors=colors)
mpf.plot(data, type='candle', style=mpf_style, volume=True)
